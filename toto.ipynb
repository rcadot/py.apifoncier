# %%
import cartofriches

apifoncier.cartofriches.geofriches(
    coddep=[
        "59",
    ]
)
# Out:
#                                                geometry  \
# 0     MULTIPOLYGON (((3.30822 50.33274, 3.30809 50.3...
# 1     MULTIPOLYGON (((3.29998 50.33121, 3.29980 50.3...
# 2     MULTIPOLYGON (((2.95449 50.53567, 2.95457 50.5...
# 3     MULTIPOLYGON (((3.14915 50.40098, 3.14913 50.4...
# 4     MULTIPOLYGON (((3.26084 50.33301, 3.26091 50.3...
# ...                                                 ...
# 1424  MULTIPOLYGON (((3.04338 50.77476, 3.04339 50.7...
# 1425  MULTIPOLYGON (((3.04156 50.77233, 3.04153 50.7...
# 1426  MULTIPOLYGON (((2.50821 50.92797, 2.50818 50.9...
# 1427  MULTIPOLYGON (((3.24048 50.63225, 3.24077 50.6...
# 1428  MULTIPOLYGON (((2.48430 50.84410, 2.48425 50.8...
#
#                             site_nom site_type site_adresse  \
# 0                carrière des Plombs   inconnu         None
# 1              Atelier de réparation   inconnu         None
# 2                        Distillerie   inconnu         None
# ...
