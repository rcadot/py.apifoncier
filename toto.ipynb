# %%
import apifoncier.ff as ff

apifoncier.configure(
    TOKEN="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjkxMjY3OTc3LCJpYXQiOjE2ODg2NzU5NzcsImp0aSI6IjMxMjI5N2I0OTlkYzQ5ZDZhMWFkY2Q0OWMyZjNmMzE3IiwidXNlcl9uYW1lIjoiYW50b2luZS5oZXJtYW4iLCJhdWQiOiJhcGlkZiJ9.vh7daN3M2GhkQE6SeOEnbsKCeDQZma9hr3r1SNtY4VQ"
)
ff.geoparcelles(code_insee=["59003", "59002"])
# Out:
# https://apidf-preprod.cerema.fr/ff/geoparcelles/?code_insee=59003&page_size=500: 100%|██████████| 1037/1037 [00:01<00:00, 946.51it/s]
# https://apidf-preprod.cerema.fr/ff/geoparcelles/?code_insee=59002&page_size=500: 100%|██████████| 2981/2981 [00:07<00:00, 376.14it/s]
#                                                geometry    idprocpte  idcom  \
# 0     MULTIPOLYGON (((4.10750 50.23681, 4.10713 50.2...  59003J00012  59003
# 1     MULTIPOLYGON (((4.10752 50.23680, 4.10749 50.2...  59003J00012  59003
# 2     MULTIPOLYGON (((4.10752 50.23680, 4.10801 50.2...  59003+00027  59003
# 3     MULTIPOLYGON (((4.11258 50.23694, 4.11239 50.2...  59003J00015  59003
# 4     MULTIPOLYGON (((4.11299 50.23696, 4.11272 50.2...  59003+00019  59003
# ...                                                 ...          ...    ...
# 4013  MULTIPOLYGON (((3.28785 50.33400, 3.28807 50.3...  59002+00297  59002
# 4014  MULTIPOLYGON (((3.28785 50.33400, 3.28781 50.3...  59002+00297  59002
# ...

# %%
gdf = apifoncier.cartofriches.friches(coddep=["59", "62", "54"])
# Out:
# https://apidf-preprod.cerema.fr/cartofriches/friches/?coddep=59&page_size=500: 100%|██████████| 1429/1429 [00:00<00:00, 2838.03it/s]
# https://apidf-preprod.cerema.fr/cartofriches/friches/?coddep=62&page_size=500: 100%|██████████| 564/564 [00:00<00:00, 4645.63it/s]
# https://apidf-preprod.cerema.fr/cartofriches/friches/?coddep=54&page_size=500: 100%|██████████| 424/424 [00:00<00:00, 119942.33it/s]

# %%
import apifoncier.ind_prix as pri

prix.aav(code_insee=["001"])
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\antoine.herman\Documents\dev\py.apifoncier\venv\Lib\site-packages\IPython\core\interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     import apifoncier.ind_prix as pri
#
#   File c:\Users\antoine.herman\Documents\dev\py.apifoncier\apifoncier\__init__.py:7
#     import apifoncier.ind_prix
#
#   File c:\Users\antoine.herman\Documents\dev\py.apifoncier\apifoncier\ind_prix.py:22
#     if periode in not ("annuel", "triennal"):
#                   ^
# SyntaxError: invalid syntax
